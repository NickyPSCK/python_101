# %% [markdown]
# # Single Customer View

# %% [markdown]
# **The Conception of Customer Single View**
#
# - RFM
#
#     - R: Recency (ex. last visit)
#     - F: Frequency (ex. total visit)
#     - M: Monetary (ex. total spend)
#
# for more information: https://medium.com/@thanachart.rit/building-customer-single-view-customer-360-3539c971092c

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('supermarket_data.csv')

# %%
df.head()
# Out:
#    SHOP_DATE  SHOP_HOUR        BASKET_ID       CUST_CODE  STORE_CODE  \
# 0   20071006         21  994107800268406  CUST0000153531  STORE00001
# 1   20070201         15  994104300305853  CUST0000219191  STORE00002
# 2   20071103         13  994108200514137  CUST0000526979  STORE00003
# 3   20070206         18  994104400743650  CUST0000913709  STORE00004
# 4   20071015         19  994108000780959  CUST0000961285  STORE00001
#
#     PROD_CODE  QUANTITY  SPEND
# 0  PRD0901391         1   0.37
# 1  PRD0901915         1   5.08
# 2  PRD0903379         1   2.36
# 3  PRD0903305         1   0.20
# 4  PRD0903387         1   1.65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671914 entries, 0 to 671913
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   SHOP_DATE   671914 non-null  int64
#  1   SHOP_HOUR   671914 non-null  int64
#  2   BASKET_ID   671914 non-null  int64
#  3   CUST_CODE   671914 non-null  object
#  4   STORE_CODE  671914 non-null  object
#  5   PROD_CODE   671914 non-null  object
#  6   QUANTITY    671914 non-null  int64
#  7   SPEND       671914 non-null  float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 41.0+ MB

# %%
df.describe()
# Out:
#           SHOP_DATE      SHOP_HOUR     BASKET_ID       QUANTITY          SPEND
# count  6.719140e+05  671914.000000  6.719140e+05  671914.000000  671914.000000
# mean   2.007391e+07      14.745869  9.941078e+14       1.514344       1.852796
# std    4.594496e+03       3.551738  2.286042e+09       1.668037       2.589564
# min    2.007010e+07       8.000000  9.941039e+14       1.000000       0.010000
# 25%    2.007052e+07      12.000000  9.941058e+14       1.000000       0.750000
# 50%    2.007093e+07      15.000000  9.941077e+14       1.000000       1.210000
# 75%    2.008022e+07      17.000000  9.941098e+14       1.000000       2.040000
# max    2.008071e+07      21.000000  9.941117e+14      73.000000     189.630000

# %%
df['SHOP_DATE'] = pd.to_datetime(df['SHOP_DATE'], format='%Y%m%d')

# %%
df.head()
# Out:
#    SHOP_DATE  SHOP_HOUR        BASKET_ID       CUST_CODE  STORE_CODE  \
# 0 2007-10-06         21  994107800268406  CUST0000153531  STORE00001
# 1 2007-02-01         15  994104300305853  CUST0000219191  STORE00002
# 2 2007-11-03         13  994108200514137  CUST0000526979  STORE00003
# 3 2007-02-06         18  994104400743650  CUST0000913709  STORE00004
# 4 2007-10-15         19  994108000780959  CUST0000961285  STORE00001
#
#     PROD_CODE  QUANTITY  SPEND
# 0  PRD0901391         1   0.37
# 1  PRD0901915         1   5.08
# 2  PRD0903379         1   2.36
# 3  PRD0903305         1   0.20
# 4  PRD0903387         1   1.65

# %%
df2 = df.groupby('CUST_CODE').SHOP_DATE.max()

# %%
df2
# Out:
# CUST_CODE
# CUST0000000107   2008-03-25
# CUST0000000369   2008-07-05
# CUST0000001388   2008-04-11
# CUST0000002302   2008-07-03
# CUST0000002637   2008-05-30
#                     ...
# CUST0000999439   2008-07-05
# CUST0000999544   2007-03-23
# CUST0000999593   2008-04-02
# CUST0000999935   2008-06-05
# CUST0000999936   2008-04-17
# Name: SHOP_DATE, Length: 4891, dtype: datetime64[ns]

# %%
type(df2)
# Out:
# pandas.core.series.Series

# %%
df3 = pd.DataFrame(df2).rename(columns={"SHOP_DATE": "LAST_VISIT"})

# %%
df3.head()
# Out:
#                LAST_VISIT
# CUST_CODE
# CUST0000000107 2008-03-25
# CUST0000000369 2008-07-05
# CUST0000001388 2008-04-11
# CUST0000002302 2008-07-03
# CUST0000002637 2008-05-30

# %%
df3["TOTAL_VISIT"] = df.groupby('CUST_CODE').BASKET_ID.nunique()

# %%
df3.head()
# Out:
#                LAST_VISIT  TOTAL_VISIT
# CUST_CODE
# CUST0000000107 2008-03-25            1
# CUST0000000369 2008-07-05          126
# CUST0000001388 2008-04-11            4
# CUST0000002302 2008-07-03           71
# CUST0000002637 2008-05-30            7

# %%
df3["TOTAL_SPEND"] = df.groupby('CUST_CODE').SPEND.sum()

# %%
df3.head()
# Out:
#                LAST_VISIT  TOTAL_VISIT  TOTAL_SPEND
# CUST_CODE
# CUST0000000107 2008-03-25            1         0.80
# CUST0000000369 2008-07-05          126       545.17
# CUST0000001388 2008-04-11            4        21.90
# CUST0000002302 2008-07-03           71       492.84
# CUST0000002637 2008-05-30            7        48.50

# %% [markdown]
# ## Exercise

# %% [markdown]
# 1. create new column as average monthly visit
#       - average monthly visit = Total visit / no. of active month
#
#
# 2. create new column as average monthly spend
#       - average monthly spend = Total spend / no. of active month
#
#
# 3. create new column as average basket size
#       - average basket size = Total spend / no. of basket
#
#
# 4. if you have time available, please create your own columns

# %%
df['YEAR'] = df['SHOP_DATE'].dt.year

# %%
df.head()
# Out:
#    SHOP_DATE  SHOP_HOUR        BASKET_ID       CUST_CODE  STORE_CODE  \
# 0 2007-10-06         21  994107800268406  CUST0000153531  STORE00001
# 1 2007-02-01         15  994104300305853  CUST0000219191  STORE00002
# 2 2007-11-03         13  994108200514137  CUST0000526979  STORE00003
# 3 2007-02-06         18  994104400743650  CUST0000913709  STORE00004
# 4 2007-10-15         19  994108000780959  CUST0000961285  STORE00001
#
#     PROD_CODE  QUANTITY  SPEND  YEAR
# 0  PRD0901391         1   0.37  2007
# 1  PRD0901915         1   5.08  2007
# 2  PRD0903379         1   2.36  2007
# 3  PRD0903305         1   0.20  2007
# 4  PRD0903387         1   1.65  2007

# %%
df['MONTH'] = df['SHOP_DATE'].dt.month

# %%
df.head()
# Out:
#    SHOP_DATE  SHOP_HOUR        BASKET_ID       CUST_CODE  STORE_CODE  \
# 0 2007-10-06         21  994107800268406  CUST0000153531  STORE00001
# 1 2007-02-01         15  994104300305853  CUST0000219191  STORE00002
# 2 2007-11-03         13  994108200514137  CUST0000526979  STORE00003
# 3 2007-02-06         18  994104400743650  CUST0000913709  STORE00004
# 4 2007-10-15         19  994108000780959  CUST0000961285  STORE00001
#
#     PROD_CODE  QUANTITY  SPEND  YEAR  MONTH
# 0  PRD0901391         1   0.37  2007     10
# 1  PRD0901915         1   5.08  2007      2
# 2  PRD0903379         1   2.36  2007     11
# 3  PRD0903305         1   0.20  2007      2
# 4  PRD0903387         1   1.65  2007     10

# %%
df['YEAR_MONTH'] = df['SHOP_DATE'].apply(lambda x: x.strftime('%Y-%m'))

# %%
df.head()
# Out:
#    SHOP_DATE  SHOP_HOUR        BASKET_ID       CUST_CODE  STORE_CODE  \
# 0 2007-10-06         21  994107800268406  CUST0000153531  STORE00001
# 1 2007-02-01         15  994104300305853  CUST0000219191  STORE00002
# 2 2007-11-03         13  994108200514137  CUST0000526979  STORE00003
# 3 2007-02-06         18  994104400743650  CUST0000913709  STORE00004
# 4 2007-10-15         19  994108000780959  CUST0000961285  STORE00001
#
#     PROD_CODE  QUANTITY  SPEND  YEAR  MONTH YEAR_MONTH
# 0  PRD0901391         1   0.37  2007     10    2007-10
# 1  PRD0901915         1   5.08  2007      2    2007-02
# 2  PRD0903379         1   2.36  2007     11    2007-11
# 3  PRD0903305         1   0.20  2007      2    2007-02
# 4  PRD0903387         1   1.65  2007     10    2007-10

# %%
df3["ACTIVE_MONTH"] = df.groupby('CUST_CODE').YEAR_MONTH.nunique()

# %%
df3.head()
# Out:
#                LAST_VISIT  TOTAL_VISIT  TOTAL_SPEND  ACTIVE_MONTH
# CUST_CODE
# CUST0000000107 2008-03-25            1         0.80             1
# CUST0000000369 2008-07-05          126       545.17            19
# CUST0000001388 2008-04-11            4        21.90             3
# CUST0000002302 2008-07-03           71       492.84            13
# CUST0000002637 2008-05-30            7        48.50             6

# %% [markdown]
# **1. Average Monthly Visit**

# %%
df3['AVG_MONTHLY_VISIT'] = df3.apply(lambda df3: df3['TOTAL_VISIT']/df3['ACTIVE_MONTH'], axis = 1)

# %%
df3.head()
# Out:
#                LAST_VISIT  TOTAL_VISIT  TOTAL_SPEND  ACTIVE_MONTH  \
# CUST_CODE
# CUST0000000107 2008-03-25            1         0.80             1
# CUST0000000369 2008-07-05          126       545.17            19
# CUST0000001388 2008-04-11            4        21.90             3
# CUST0000002302 2008-07-03           71       492.84            13
# CUST0000002637 2008-05-30            7        48.50             6
#
#                 AVG_MONTHLY_VISIT
# CUST_CODE
# CUST0000000107           1.000000
# CUST0000000369           6.631579
# CUST0000001388           1.333333
# CUST0000002302           5.461538
# CUST0000002637           1.166667

# %% [markdown]
# **2. Average Monthly Spend**

# %%
df3['AVG_MONTHLY_SPEND'] = df3.apply(lambda df3: df3['TOTAL_SPEND']/df3['ACTIVE_MONTH'], axis = 1)

# %%
df3.head()
# Out:
#                LAST_VISIT  TOTAL_VISIT  TOTAL_SPEND  ACTIVE_MONTH  \
# CUST_CODE
# CUST0000000107 2008-03-25            1         0.80             1
# CUST0000000369 2008-07-05          126       545.17            19
# CUST0000001388 2008-04-11            4        21.90             3
# CUST0000002302 2008-07-03           71       492.84            13
# CUST0000002637 2008-05-30            7        48.50             6
#
#                 AVG_MONTHLY_VISIT  AVG_MONTHLY_SPEND
# CUST_CODE
# CUST0000000107           1.000000           0.800000
# CUST0000000369           6.631579          28.693158
# CUST0000001388           1.333333           7.300000
# CUST0000002302           5.461538          37.910769
# CUST0000002637           1.166667           8.083333

# %% [markdown]
# **3. Average Basket size**

# %%
df3['AVG_BASKET_SIZE'] = df3.apply(lambda df3: df3['TOTAL_SPEND']/df3['TOTAL_VISIT'], axis = 1)

# %%
df3.head()
# Out:
#                LAST_VISIT  TOTAL_VISIT  TOTAL_SPEND  ACTIVE_MONTH  \
# CUST_CODE
# CUST0000000107 2008-03-25            1         0.80             1
# CUST0000000369 2008-07-05          126       545.17            19
# CUST0000001388 2008-04-11            4        21.90             3
# CUST0000002302 2008-07-03           71       492.84            13
# CUST0000002637 2008-05-30            7        48.50             6
#
#                 AVG_MONTHLY_VISIT  AVG_MONTHLY_SPEND  AVG_BASKET_SIZE
# CUST_CODE
# CUST0000000107           1.000000           0.800000         0.800000
# CUST0000000369           6.631579          28.693158         4.326746
# CUST0000001388           1.333333           7.300000         5.475000
# CUST0000002302           5.461538          37.910769         6.941408
# CUST0000002637           1.166667           8.083333         6.928571

# %% [markdown]
# ## More Questions
# 1.How many members?
#
# 2.How much each store sales?
#
# 3.Which item was the most popular by quantity?
#
# 4.Which member had the highest sum spend?
#
# 5.How many members who spend more than 100 in 2007?
#
# 6.How much average spend each hour?
#
# 7.How many days that has sum spend more than 3000?
#
# 8.What date has sum spend more than 4000 and how much sum spend each date?

# %%
# 1
df['CUST_CODE'].nunique()
# Out:
# 4891

# %%
# 2
df.loc[:, ['STORE_CODE', 'SPEND']].groupby('STORE_CODE').sum()
# Out:
#                 SPEND
# STORE_CODE
# STORE00001  399724.15
# STORE00002  217743.62
# STORE00003  415341.33
# STORE00004  212110.27

# %%
# 3
df.loc[:, ['PROD_CODE', 'QUANTITY']].groupby('PROD_CODE').sum().sort_values(by = 'QUANTITY', ascending = False)
# Out:
#             QUANTITY
# PROD_CODE
# PRD0903678     92694
# PRD0904358     15738
# PRD0903052     15587
# PRD0900121     12861
# PRD0903269      7234
# ...              ...
# PRD0904259         1
# PRD0900395         1
# PRD0904423         1
# PRD0903544         1
# PRD0902133         1
#
# [4978 rows x 1 columns]

# %%
# 4
df.loc[:, ['CUST_CODE', 'SPEND']].groupby('CUST_CODE').sum().sort_values(by = 'SPEND', ascending = False)
# Out:
#                    SPEND
# CUST_CODE
# CUST0000123240  10149.73
# CUST0000783041   8045.70
# CUST0000455778   7164.68
# CUST0000942162   5528.45
# CUST0000372422   5156.49
# ...                  ...
# CUST0000902099      0.01
# CUST0000478503      0.01
# CUST0000179503      0.01
# CUST0000309335      0.01
# CUST0000538443      0.01
#
# [4891 rows x 1 columns]

# %%
# 5
cust_2007 = df.loc[(df['YEAR'] == 2007), ['CUST_CODE', 'SPEND']].groupby('CUST_CODE').sum()
cust_2007[cust_2007['SPEND'] > 100].shape
# Out:
# (1271, 1)

# %%
# 6
df.loc[:, ['SHOP_HOUR', 'SPEND']].groupby('SHOP_HOUR').mean()
# Out:
#               SPEND
# SHOP_HOUR
# 8          1.859958
# 9          1.821021
# 10         1.801998
# 11         1.807770
# 12         1.818270
# 13         1.831760
# 14         1.851879
# 15         1.839337
# 16         1.860795
# 17         1.856006
# 18         1.893713
# 19         1.911337
# 20         1.934999
# 21         1.887355

# %%
# 7
shop_date_df = df.loc[:, ['SHOP_DATE', 'SPEND']].groupby('SHOP_DATE').sum()
shop_date_df[shop_date_df['SPEND'] > 3000]
# Out:
#               SPEND
# SHOP_DATE
# 2007-03-13  3161.41
# 2007-06-15  3157.59
# 2007-07-10  3023.30
# 2007-12-17  3226.08
# 2007-12-19  3402.47
# 2007-12-20  4833.46
# 2007-12-21  3380.47
# 2007-12-22  3000.13
# 2007-12-23  3271.74

# %%
# 8
shop_date_df = df.loc[:, ['SHOP_DATE', 'SPEND']].groupby('SHOP_DATE').sum()
shop_date_df[shop_date_df['SPEND'] > 4000]
# Out:
#               SPEND
# SHOP_DATE
# 2007-12-20  4833.46
